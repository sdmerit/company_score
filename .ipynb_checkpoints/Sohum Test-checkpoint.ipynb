# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Sohum Test Notebook
# A notebook created by Sohum to play around with and refresh skills. Not meant to be taken too seriously, but more for the fun of relearning DS skills.
